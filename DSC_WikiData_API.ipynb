# %%
# !pip install wikidata

# %%
from wikidata.client import Client

# %% [markdown]
# Testing out API using FDR

# %%
client = Client()

# %%
entity = client.get('Q8007', load=True)

# %%
entity.description
# Out:
# m'president of the United States from 1933 to 1945'

# %%
image_prop = client.get('P18')

# %%
image = entity[image_prop]

# %%
image
# Out:
# <wikidata.commonsmedia.File 'File:FDR 1944 Color Portrait.jpg'>

# %%
image.image_resolution
# Out:
# (2754, 3969)

# %%
image.image_url
# Out:
# 'https://upload.wikimedia.org/wikipedia/commons/4/42/FDR_1944_Color_Portrait.jpg'
